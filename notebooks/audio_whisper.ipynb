# %%
import torch
import whisper
import os

# Çalışma dizinini tangible klasörüne ayarla
os.chdir('..')

# Şu anki çalışma dizinini kontrol et
print(os.getcwd())
# Out:
# c:\Users\user\Documents\Python Projects\tangible

# %%
# 1) Modeli yükle (ör: 'medium' modelini seçelim)
model_name = "medium"
device = "cuda" if torch.cuda.is_available() else "cpu"
model = whisper.load_model(model_name, device=device)

# 2) Transkribe edilecek dosya yolunu belirtin (örnek: test.wav)
audio_file_path = "data/Görüşme8 Esra Tan.m4a"
print("Dosya var mı?:", os.path.isfile(audio_file_path))

# 3) Transkripsiyon yap
#    Otomatik dil tespiti yapmak isterseniz "language" parametresini kaldırabilirsiniz
transcription_result = model.transcribe(audio_file_path, language="tr")

# 4) Sonucu yazdır
print(transcription_result["text"])

# 5) Sonucu bir metin dosyasına kaydetmek isterseniz
with open("data/transcription.txt", "w", encoding="utf-8") as f:
    f.write(transcription_result["text"])
# Out:
# c:\Users\user\Documents\Python Projects\tangible\venv_whisper\Lib\site-packages\whisper\__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# Dosya var mı?: True
# c:\Users\user\Documents\Python Projects\tangible\venv_whisper\Lib\site-packages\whisper\transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  Hocam kameram şu an kapalı değil mi? Şu an kapalı, sadece sesli görüşme yapacağız. Bugün 23 Eylül 2024 saatimiz 17.30 civarı. Şu an Eda Hanım'la görüşüyoruz. Eda Fırlangetsk görüşmemiz kayıt altında ve Eda Hanım'ın bilgisi dairinde. Eda Hanım hoş geldiniz ve teşekkür ediyorum öncelikle bu çalışmaya desteğiniz için. Siz tanıyarak başlayabilir miyiz? Siz nerede yaşıyorsunuz, ne yapıyorsunuz, eğitim yaşantınız nedir, geçmiş eğitim yaşantınızdan biraz bahsederseniz böyle kendinle tanıtırsanız sevinirim. Şöyle ben Eda Fırlangetsk, 28.07.1997 doğumluyum. Eğitim hayatımdan daha çok bahsetmek isterim. Bir müddet örgün okudum, daha sonra işler yolunda gitmedi ve ikinci lisansım olan, aslında ilk lisans, bitirilmiş ilk lisansım olan sosyolojiye yatay geçiş yaptım. Yani ikinci üniversite kapsamında. Örgündeki bölüm neydi? Öbürü edebiyat şu an devam ediyorum zaten. Şöyle açıklayayım, biraz karışıklık var. Şimdi şöyle, Ahi Evran Üniversitesi'nde örgün eğitim, edebiyata başlamıştım. Aynı zamanda çalışıyorum. Böyle olunca biraz yolunda gitmedi bazı şeyler ve edebiyatı o an askıya alman zorunda kaldım. Edebiyatı referans göstererek de Anadolu Üniversitesi'nde mesela böyle bir imkan var. İkinci üniversite kapsamında sosyoloji lisans bitirdim. Daha sonrasında tam bittiği süreçte, aynı süreçte Anadolu Üniversitesi'nin yatay geçişleri açıldı. Örgün Üniversitesi'ni